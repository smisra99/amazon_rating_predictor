# %%
import pandas as pd
def convert_dtype(x):
    if not x:
        return 0
    try:
        return int(float(x))   
    except:        
        return 0
df = pd.read_csv("Clothing_Shoes_and_Jewelry_10.csv", converters={'vote': convert_dtype,'overall':convert_dtype})

# %%
df.reviewText = df.reviewText.fillna('')
df.summary = df.summary.fillna('')
df['FinalReviewText'] = df['reviewText'] + ' ' + df['summary']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

def data_cleaning(row):

  row = row.lower()
  row = re.sub('[^A-Za-z]+', ' ', row)

  text_tokens = word_tokenize(row)
  stop_words = stopwords.words('english')

  list_clean_words = [word for word in text_tokens if not word in stopwords.words()]

  lemmatize = WordNetLemmatizer()
  for i in range(len(list_clean_words)):
    list_clean_words[i] = lemmatize.lemmatize(list_clean_words[i])
  row = ' '.join(list_clean_words)
  return row
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kheni\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kheni\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kheni\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kheni\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = pd.DataFrame(df.head(100))
result = []
for x in df['FinalReviewText']:
    result.append(data_cleaning(x))
df['FinalReviewText'] = result

# %%
df.head(10)
# Out:
#    overall  vote  verified                                         reviewText  \
# 0        2     0      True                           too small ok for a child
# 1        5     5      True  VERY SOFT!!! I bought a size large for my daug...
# 2        4     0      True  The shoe fits nicely, but as as comfortable in...
# 3        3     0      True  We are huge Keen fans. I have purchased this e...
# 4        1     0      True  When I received watch the pin was already pull...
# 5        2     0      True  Does not look like the  picture bow in the fro...
# 6        5     0      True  This dress looks fabulous on me!  It shipped s...
# 7        5     0      True  One of my nephews wears Converse and another w...
# 8        5     5      True  I bought these shoes for my 3.5 yr old daughte...
# 9        5     0      True  I was pleasantly surprised. The XXL size fits ...
#
#                                              summary  \
# 0                                          Two Stars
# 1  SO SOFT! I wish I could buy some in Adult size...
# 2                                        shoe review
# 3                                       Not thrilled
# 4                             pin was already pulled
# 5  Does not look like the picture bow in the fron...
# 6                         It shipped super fast, too
# 7                             Grat High-top Chuck's!
# 8                       They are a great winter boot
# 9  The XXL size fits great! (I am a size 18 and 5...
#
#                                      FinalReviewText
# 0                            small ok child two star
# 1  soft bought size large daughter bigger foot ye...
# 2  shoe fit nicely comfortable heel area somewhat...
# 3  huge keen fan purchased exact style directly k...
# 4  received watch pin already pulled watch work d...
# 5  look like picture bow front extremely cheap lo...
# 6  dress look fabulous shipped super fast weigh a...
# 7  nephew wear converse another wear nike purchas...
# 8  bought shoe yr old daughter moved oregon great...
# 9  pleasantly surprised xxl size fit great size w...
